# %%
#Here is the map requested for the assignment
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
 

map = Basemap(projection='ortho', lat_0=50, lon_0=-100,
              resolution='l', area_thresh=1000.0)
 
map.drawcoastlines()
map.drawcountries()
map.fillcontinents(color='coral')
map.drawmapboundary()
 
plt.show()

# %%
#When I accidentally worked ahead, I tried to set the resolution to "high," as directed by the instructions.
#As you can tell, this didn't work.
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
 
#Resolution = 'h'
map = Basemap(projection='merc', lat_0=57, lon_0=-135,
resolution = 'h', area_thresh = 0.1,
    llcrnrlon=-136.25, llcrnrlat=56,
    urcrnrlon=-134.25, urcrnrlat=57.75)
 
map.drawcoastlines()
map.drawcountries()
map.fillcontinents(color='coral')
map.drawmapboundary()
 
map.drawmeridians(np.arange(0, 360, 30))
map.drawparallels(np.arange(-90, 90, 30))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-22c7e033f780> in <module>()
#       9 resolution = 'h', area_thresh = 0.1,
#      10     llcrnrlon=-136.25, llcrnrlat=56,
# ---> 11     urcrnrlon=-134.25, urcrnrlat=57.75)
#      12
#      13 map.drawcoastlines()
#
# C:\Users\valenzak\AppData\Local\Enthought\Canopy32\User\lib\site-packages\mpl_toolkits\basemap\__init__.py in __init__(self, llcrnrlon, llcrnrlat, urcrnrlon, urcrnrlat, llcrnrx, llcrnry, urcrnrx, urcrnry, width, height, projection, resolution, area_thresh, rsphere, ellps, lat_ts, lat_1, lat_2, lat_0, lon_0, lon_1, lon_2, o_lon_p, o_lat_p, k_0, no_rot, suppress_ticks, satellite_height, boundinglat, fix_aspect, anchor, celestial, round, epsg, ax)
#    1077         if self.resolution is not None:
#    1078             self.coastsegs, self.coastpolygontypes =\
# ...

# %%
#Setting the resolution to intermediate achieved a clearer map than the low setting, and it still worked.
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
 
#resolution = 'i'
map = Basemap(projection='merc', lat_0=57, lon_0=-135,
resolution = 'i', area_thresh = 0.1,
    llcrnrlon=-136.25, llcrnrlat=56,
    urcrnrlon=-134.25, urcrnrlat=57.75)
 
map.drawcoastlines()
map.drawcountries()
map.fillcontinents(color='coral')
map.drawmapboundary()
 
map.drawmeridians(np.arange(0, 360, 30))
map.drawparallels(np.arange(-90, 90, 30))

plt.show()

# %%
#Here is the same area on the low resolution setting
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
 
#resolution = 'l'
map = Basemap(projection='merc', lat_0=57, lon_0=-135,
resolution = 'l', area_thresh = 0.1,
    llcrnrlon=-136.25, llcrnrlat=56,
    urcrnrlon=-134.25, urcrnrlat=57.75)
 
map.drawcoastlines()
map.drawcountries()
map.fillcontinents(color='coral')
map.drawmapboundary()
 
map.drawmeridians(np.arange(0, 360, 30))
map.drawparallels(np.arange(-90, 90, 30))

plt.show()
